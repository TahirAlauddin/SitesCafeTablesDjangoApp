# %%
import sqlite3

# %%
db = sqlite3.connect('db.sqlite3')
cursor = db.cursor()

# %%
import pandas as pd

# %%
df = pd.read_sql("SELECT * FROM cafe_record", db, index_col='id')

# %%
df
# Out:
#                      date_time                          table_id  allocated  \
# id
# 7   2022-05-21 09:58:16.353400                              None          0
# 8   2022-05-21 09:58:16.401401                              None          0
# 9   2022-05-21 09:59:35.502205                              None          0
# 10  2022-05-21 09:59:35.542183                              None          0
# 11  2022-05-21 10:09:40.255480                              None          1
# 12  2022-05-21 10:10:08.163406                              None          0
# 13  2022-05-21 10:18:50.135862                              None          1
# 14         2022-05-21 10:20:23                              None          1
# 15  2022-05-21 10:23:14.151321  25daf3ba912a411b8de885056845887c          1
# 16  2022-05-21 10:23:20.582421                              None          1
#
#                                         deleted_table
# id
# 7   cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...
# ...

# %%
df['table'] = df['table_id'] + df['deleted_table']

# %%
import numpy as np

# %%
df.replace('None', )
# Out:
#                      date_time                          table_id  allocated  \
# id
# 7   2022-05-21 09:58:16.353400                              None          0
# 8   2022-05-21 09:58:16.401401                               NaN          0
# 9   2022-05-21 09:59:35.502205                              None          0
# 10  2022-05-21 09:59:35.542183                               NaN          0
# 11  2022-05-21 10:09:40.255480                               NaN          1
# 12  2022-05-21 10:10:08.163406                               NaN          0
# 13  2022-05-21 10:18:50.135862                              None          1
# 14         2022-05-21 10:20:23                              None          1
# 15  2022-05-21 10:23:14.151321  25daf3ba912a411b8de885056845887c          1
# 16  2022-05-21 10:23:20.582421                              None          1
#
#                                         deleted_table
# id
# 7   cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [date_time, table_id, allocated, deleted_table]
# Index: []

# %%
df2 = df[['table_id', 'deleted_table']].apply(lambda x: x['table_id'] if x['table_id'] else x['deleted_table'], axis=1)
# (lambda x: x['table_id'] if x['table_id'] else x['deleted_table'] )
df2
# Out:
# id
# 7     cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...
# 8                                                   NaN
# 9     cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    cafe= label=T1 id=bb840e3c-869e-4d5b-8092-07af...
# 14    cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...
# 15                     25daf3ba912a411b8de885056845887c
# 16    cafe= label=T2 id=163fa050-2bae-423f-b350-6d44...
# dtype: object

# %%
df
# Out:
#                      date_time                          table_id  allocated  \
# id
# 7   2022-05-21 09:58:16.353400                              None          0
# 8   2022-05-21 09:58:16.401401                              None          0
# 9   2022-05-21 09:59:35.502205                              None          0
# 10  2022-05-21 09:59:35.542183                              None          0
# 11  2022-05-21 10:09:40.255480                              None          1
# 12  2022-05-21 10:10:08.163406                              None          0
# 13  2022-05-21 10:18:50.135862                              None          1
# 14         2022-05-21 10:20:23                              None          1
# 15  2022-05-21 10:23:14.151321  25daf3ba912a411b8de885056845887c          1
# 16  2022-05-21 10:23:20.582421                              None          1
#
#                                         deleted_table table
# id
# 7   cafe= label=T1 id=669d4a24-789f-4625-8c5c-b1ff...   NaN
# ...
